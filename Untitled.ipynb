# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import glob

path = r'/Users/twochanz/capterra/data' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, encoding='latin-1')
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
test = df.head()
test
# Out:
#    company                                              title         name  \
# 0  picatix  Well-rounded event management tool for non-pro...      Phil O.
# 1  picatix  Easy to use ticketing product with a very reas...    Amanda G.
# 2  picatix                               Simple And effective      Mike D.
# 3  picatix  Outstanding platform that handles my events li...  Jennifer S.
# 4  picatix  As an event planner, I am looking for ease of ...  Jennifer D.
#
#                                             position  \
# 0  Team Lead, Student Recruitment and Prospective...
# 1                             Director, Brand Design
# 2                                              Owner
# 3                                                CEO
# 4                           Owner & Lead Coordinator
#
#                                industry                               usage  \
# 0  Higher Education, 501-1000 employees     Used the software for: 2+ years
# 1           Automotive, 11-50 employees    Used the software for: 1-2 years
# 2                                   NaN     Used the software for: 2+ years
# 3                                   NaN  Used the software for: 6-12 months
# 4                                   NaN     Used the software for: 2+ years
#
#   paid_status            source       date  total  ease  feature  support  \
# 0          NO  Source: Capterra  11-May-18      5   5.0      4.0        5
# 1          NO    Source: GetApp  24-Mar-16      5   5.0      4.0        5
# 2          NO  Source: Capterra  11-May-18      5   5.0      4.0        5
# 3          NO  Source: Capterra  11-May-18      5   5.0      5.0        5
# 4          NO  Source: Capterra  17-May-18      5   5.0      5.0        5
#
#    value  recommend                                           comments  \
# 0      4         10                                                NaN
# 1      4         10  Comments: Our company needed registration for ...
# 2      4         10                                                NaN
# 3      4         10                                                NaN
# 4      4         10                                                NaN
#
#                                                 pros  \
# 0  Pros: I've used Picatic across a two post-seco...
# 1  Pros: As mentioned, the management tools were ...
# 2  Pros: Super easy to use and doesn't have any g...
# 3  Pros: I love that it is so easy to use. The st...
# 4  Pros: - Ease of use for setting up events\r\r-...
#
#                                                 cons  \
# 0  Cons: Some of what makes the software the simp...
# 1  Cons: There are a few features missing. (I und...
# 2  Cons: Wish that I could do T-shirt sizes and a...
# 3  Cons: I love it all. There is nothing that I d...
# 4  Cons: I have yet to find a Con with Picatic. I...
#
#                                              overall  \
# 0  Overall: This software provides a single tool ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   recommendations to other buyers
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
df.shape
# Out:
# (5475, 20)

# %%
df.groupby('company').describe()
# Out:
#                        total                                               \
#                        count      mean       std  min  25%  50%  75%  max
# company
# accelevents             78.0  4.820513  0.418519  3.0  5.0  5.0  5.0  5.0
# accesso_showare         44.0  4.659091  0.525763  3.0  4.0  5.0  5.0  5.0
# attendstar              62.0  4.661290  0.599003  3.0  4.0  5.0  5.0  5.0
# bookwhen                87.0  4.816092  0.389655  4.0  5.0  5.0  5.0  5.0
# brushfire               80.0  4.662500  0.635326  2.0  4.0  5.0  5.0  5.0
# event_essentials        64.0  4.953125  0.213042  4.0  5.0  5.0  5.0  5.0
# eventbank               43.0  4.697674  0.464701  4.0  4.0  5.0  5.0  5.0
# eventbrite            1902.0  4.582019  0.652235  1.0  4.0  5.0  5.0  5.0
# eventix                777.0  4.619048  0.524205  3.0  4.0  5.0  5.0  5.0
# gesture                 76.0  4.605263  0.674862  1.0  4.0  5.0  5.0  5.0
# givesmart               76.0  4.605263  0.674862  1.0  4.0  5.0  5.0  5.0
# ticket_tailor          181.0  4.872928  ...   5.0  5.0     181.0   9.624309
# ticketsource           308.0  4.597403  ...   5.0  5.0     308.0   9.944805
# tix                    138.0  4.702899  ...   5.0  5.0     138.0   9.753623
# townscript              52.0  4.730769  ...   5.0  5.0      52.0   9.250000
# vbo_tickets             76.0  4.197368  ...   5.0  5.0      76.0   9.236842
# vendini                 65.0  4.661538  ...   5.0  5.0      65.0   8.584615
# weemss                  50.0  4.600000  ...   5.0  5.0      50.0   9.300000
#
#
#                            std   min    25%   50%   75%   max
# company
# accelevents           0.720288   6.0   9.25  10.0  10.0  10.0
# accesso_showare       0.963115   7.0   8.00   8.0  10.0  10.0
# attendstar            1.436842   5.0   8.25  10.0  10.0  10.0
# bookwhen              1.063853   5.0  10.00  10.0  10.0  10.0
# brushfire             1.341582   3.0   9.00  10.0  10.0  10.0
# event_essentials      0.663684   8.0  10.00  10.0  10.0  10.0
# eventbank             0.841872   8.0   9.00  10.0  10.0  10.0
# eventbrite            1.433041   1.0   8.00   9.0  10.0  10.0
# eventix               1.303859   2.0   8.00   9.0  10.0  10.0
# gesture               1.323671   4.0   8.00   9.0  10.0  10.0
# givesmart             1.323671   4.0   8.00   9.0  10.0  10.0
# mytrs                 2.106937   1.0   8.00   9.0  10.0  10.0
# osconcert             1.134973   6.0   8.00  10.0  10.0  10.0
# picatix               1.298428   3.0   8.00   9.0  10.0  10.0
# purplepass_ticketing  0.738772   6.0  10.00  10.0  10.0  10.0
# repairshopr           1.967787   1.0   9.00  10.0  10.0  10.0
# sap_event_ticketing        NaN  10.0  10.00  10.0  10.0  10.0
# seatadvisor           0.758547   8.0   8.00   9.0   9.0  10.0
# silent_auction_pro    1.556009   3.0   9.00  10.0  10.0  10.0
# simpletix             1.745514   1.0  10.00  10.0  10.0  10.0
# sparxo                1.520105   3.0   9.00  10.0  10.0  10.0
# thundertix            1.066224   4.0   9.00  10.0  10.0  10.0
# ticket_tailor         0.634442   7.0   9.00  10.0  10.0  10.0
# ticketsource          0.411803   6.0  10.00  10.0  10.0  10.0
# tix                   0.509925   8.0  10.00  10.0  10.0  10.0
# townscript            1.234710   5.0   9.00  10.0  10.0  10.0
# vbo_tickets           1.056641   5.0   9.00  10.0  10.0  10.0
# vendini               2.142518   3.0   7.00  10.0  10.0  10.0
# weemss                0.974156   6.0   9.00  10.0  10.0  10.0
#
# [29 rows x 48 columns]

# %%
df['source'].value_counts()
# Out:
# Source: Capterra           4756
# Source: Software Advice     636
# Source: GetApp               83
# Name: source, dtype: int64

# %%
tipsGrid = sns.FacetGrid(tips, row='sex', col='smoker', hue='time', palette="Set2")
tipsGrid.map(sns.regplot,'total_bill','tip')
tipsGrid.add_legend()

# %%
def strip_category_name(df, column_string):
    for entry in df[column_string]:
        after = re.compile(":(.+)$")
        print after.search(entry).group(1)
# Out:
# <re.Match object; span=(0, 0), match=''>

# %%
after = re.compile(":(.+)$")
print after.search("Source: from test").group(1)
# Out:
#   File "<ipython-input-33-bf21e966dc9f>", line 2
#     print after.search("Source: from test").group(1)
#               ^
# SyntaxError: invalid syntax
