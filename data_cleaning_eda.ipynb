# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import glob

path = r'/Users/twochanz/capterra/data' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, encoding='latin-1')
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
test = df.head()
test
# Out:
#                       company                                   title  \
# 0  explara ticketing software          The Explara Ticketing Platform
# 1  explara ticketing software             Best DIY ticketing Software
# 2  explara ticketing software                 The Review that matters
# 3  explara ticketing software                   Customer Satisfaction
# 4  explara ticketing software  Explara for a social venture (startup)
#
#                 name                  position  \
# 0          Ayushi M.  Marketing & Partnerships
# 1         Prakhar D.              Engineer-P&P
# 2  Verified Reviewer                       NaN
# 3     SENGUTTUVAN C.        Director Technical
# 4  Verified Reviewer                       NaN
#
#                                             industry  \
# 0                    Events Services, 1-10 employees
# 1                Program Development, 1-10 employees
# 2  Non-Profit Organization Management, 1-10 emplo...
# ...

# %%
df.shape
# Out:
# (6445, 20)

# %%
df.groupby('company').describe()
# Out:
#                               total                                            \
#                               count      mean       std  min   25%  50%   75%
# company
# accelevents                    78.0  4.820513  0.418519  3.0  5.00  5.0  5.00
# accesso_showare                44.0  4.659091  0.525763  3.0  4.00  5.0  5.00
# agile ticketing                16.0  4.500000  0.632456  3.0  4.00  5.0  5.00
# arts people                    16.0  4.750000  0.577350  3.0  5.00  5.0  5.00
# attendstar                     62.0  4.661290  0.599003  3.0  4.00  5.0  5.00
# audienceview                    6.0  4.166667  0.752773  3.0  4.00  4.0  4.75
# backstage                      11.0  5.000000  0.000000  5.0  5.00  5.0  5.00
# betterez                       14.0  4.714286  0.468807  4.0  4.25  5.0  5.00
# big tickets                    20.0  4.900000  0.307794  4.0  5.00  5.0  5.00
# bookitbee                       8.0  4.875000  0.353553  4.0  5.00  5.0  5.00
# ...

# %%
df['source'].value_counts()
# Out:
# Source: Capterra           5644
# Source: Software Advice     650
# Source: GetApp               87
# Name: source, dtype: int64

# %%
# tipsGrid = sns.FacetGrid(tips, row='sex', col='smoker', hue='time', palette="Set2")
# tipsGrid.map(sns.regplot,'total_bill','tip')
# tipsGrid.add_legend()

# %%
def strip_category_name(df, column_string):
    for entry in df[column_string]:
        after = re.compile(": ?(.+)$")
        entry = after.search(entry).group(1)

# %%
strip_category_name(test, 'source')
test.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-debaf2f7c650> in <module>
# ----> 1 strip_category_name(test, 'source')
#       2 test.head()
#
# <ipython-input-44-f32f8e8775dc> in strip_category_name(df, column_string)
#       2     for entry in df[column_string]:
#       3         after = re.compile(": ?(.+)$")
# ----> 4         entry = after.search(entry).group(1)
#
# TypeError: expected string or bytes-like object

# %%
after = re.compile(": ?(.+)$")
print(after.search("Source: from test").group(1))
print(after.search("Source:from test").group(1))
# Out:
# from test
# from test
