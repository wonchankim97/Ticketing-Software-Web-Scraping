# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import datetime

# %%
import glob

path = r'/Users/twochanz/capterra/data' # use your path
all_files = glob.glob(path + "/*.xlsx")

li = []

for filename in all_files:
    df = pd.read_excel(filename, index_col=None, header=0, encoding='iso-8859-1')
    li.append(df)

reviews = pd.concat(li, axis=0, ignore_index=True)

# %%
# reviews.to_csv('../test.csv')

# %%
# tipsGrid = sns.FacetGrid(tips, row='sex', col='smoker', hue='time', palette="Set2")
# tipsGrid.map(sns.regplot,'total_bill','tip')
# tipsGrid.add_legend()

# %%
df = reviews.copy()

# %%
df[df.date.isnull()==True] # none of the dates are NA
# Out:
# Empty DataFrame
# Columns: [company, title, name, position, industry, usage, paid_status, source, date, total, ease, feature, support, value, recommend, comments, pros, cons, overall, recommendations to other buyers]
# Index: []

# %%
df.dtypes
# Out:
# company                                    object
# title                                      object
# name                                       object
# position                                   object
# industry                                   object
# usage                                      object
# paid_status                                object
# source                                     object
# date                               datetime64[ns]
# total                                       int64
# ease                                      float64
# feature                                   float64
# support                                   float64
# value                                     float64
# recommend                                 float64
# comments                                   object
# pros                                       object
# cons                                       object
# overall                                    object
# recommendations to other buyers            object
# dtype: object

# %%
def after_comma(x):
    try:
        return re.match(".*,\s(.*)\s.+", x).group(1)
    except:
        return ""

def before_comma(x):
    try:
        return re.match("(.*),", x).group(1)
    except:
        return ""

# %%
df['source'] = df['source'].str.replace('Source: ?', "")
df['usage'][df['usage'].str.find('Used the software for: ') == -1] = ""
df['usage'] = df['usage'].str.replace('Used the software for: ?', "")
df['comments'] = df['comments'].str.replace('Comments: ?', "")
df['pros'] = df['pros'].str.replace('Pros: ?', "")
df['cons'] = df['cons'].str.replace('Cons: ?', "")
df['overall'] = df['overall'].str.replace('Overall: ?', "")
df['recommendations to other buyers'] = df['recommendations to other buyers'].str.replace('Recommendations to other buyers: ?', "")
df['employees'] = df['industry'].map(after_comma)
df['industry'] = df['industry'].map(before_comma)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#                  company                                              title  \
# 0                    tix     Tix Cares! *Best ticketing Company...Bar none.
# 1                    tix  Couldn't be more pleased with Tix, Inc.'s web ...
# 2                    tix  TIX is the answer we needed--Great support and...
# 3                    tix  The Excellent Customer Service has made workin...
# 4                    tix  Great ticket company and excellent customer se...
# 5                    tix  Simple, Great Customer Service that is always ...
# 6                    tix                          Best choice for the price
# 7                    tix  A well layed-out system overall, with great po...
# 8                    tix                                 Love this program.
# 9                    tix                     Annual June Dance Performances
# 10                   tix                   Easy, efficient and inexpensive!
# 11                   tix                         Tix.com the service to use
# 12                   tix                Great customer service and support!
# 13                   tix                          Great experience with Tix
# 14                   tix  We love Tix! user-friendly and great support s...
# 15                   tix  Tix online ticketing solution should be your f...
# 16                   tix                               Its a learning curve
# 17                   tix  I always get the answer and instruction that I...
# 18                   tix         Perfect solution for our community theater
# 19                   tix                       NMTA Annual Event Tix Review
# 20                   tix                                         Tix Review
# 21                   tix  Tix gives us real-time event information, and ...
# 22                   tix                                Tix: Great service!
# 23                   tix                                   A great product.
# 24                   tix                            Customer Service ROCKS!
# 25                   tix  Excellent ticketing software for setting up ev...
# 26                   tix  This has made running a theater and selling ti...
# 27                   tix                         New Depot Players Love Tix
# 28                   tix  Customer service is stellar. We couldn't be ha...
# 29                   tix  We are extremely pleased with our Tix.com expe...
# ...                  ...                                                ...
# 6415  tessitura software                                   Tessitura review
# 6416  tessitura software  I've been using Tessitura for a few months and...
# 6417  tessitura software                    Great intent difficult to learn
# 6418  tessitura software                              Art Organization Zeus
# 6419  tessitura software  An incredibly robust ticketing and seating sof...
# 6420  tessitura software  Tessitura is an easy to use fundraising and ti...
# 6421  tessitura software                    Hard to Learn, Lots of Features
# 6422  tessitura software                                          Tessitura
# 6423  tessitura software                     Great but clunky and expensive
# 6424  tessitura software                         Nonprofit Arts Endorsement
# 6425  tessitura software                      A Beast that can work for you
# 6426  tessitura software  I enjoyed this software immensely, but because...
# 6427  tessitura software             Great for Customer Experience training
# 6428  tessitura software                                   Tessitura Basics
# 6429     agile ticketing  Exceptionally robust ticketing platform to mee...
# 6430     agile ticketing              What is Agile and Why Does It Matter?
# 6431     agile ticketing  Agile is an excellent solution to the ticketin...
# 6432     agile ticketing  extremely positive! We have used it for 5+ yea...
# 6433     agile ticketing  The software has saved us countless data entry...
# 6434     agile ticketing  I have been working with Agile for many years ...
# 6435     agile ticketing  Agile helped us streamline our ticket sale pro...
# 6436     agile ticketing  Excellent system. It is quite robust, without ...
# 6437     agile ticketing  Agile has surpassed our expectations and needs...
# 6438     agile ticketing                                    Agile is Great!
# 6439     agile ticketing                            Great customer service.
# 6440     agile ticketing                                     We love Agile!
# 6441     agile ticketing  Agile Ticketing is the most comprehensive tick...
# 6442     agile ticketing                             Best decision we made!
# 6443     agile ticketing                          Worthy of Your Investment
# 6444     agile ticketing                                                NaN
#
#                    name                                    position  \
# 0            Beatriz B.                       Marketing Coordinator
# 1           Carleton U.                                   Treasurer
# 2           Jennifer E.                    Data Systems Coordinator
# 3               Rita A.                          Box Office Manager
# 4               Alan G.                          Box Office Manager
# 5                 AJ M.                          Operations Manager
# 6                Jim N.                                    Direcotr
# 7              David E.                                  Supervisor
# 8              Donna F.                         Executive assistant
# 9             Janice B.                     Owner/Artistic Director
# 10             Ellie S.                Director of Visitor Services
# 11            Dustin P.                             Media Relations
# 12             Cindy H.                                         NaN
# 13            Krista S.                  Special Events Coordinator
# 14               Tim F.                                    Director
# 15               Jon H.                                    Producer
# 16             Robyn F.                  Special Events Coordinator
# 17            Pamela J.                          Operations Manager
# 18              Evan F.                                   Treasurer
# 19             Jacob O.                             Account Manager
# 20           Michael D.                                   President
# 21            Sherry I.                     Development Coordinator
# 22             David S.                           Managing Director
# 23            Robert M.                                         NaN
# 24             Terri S.                                    Co-Owner
# 25            Judith M.                                    Producer
# 26         Sebastian F.                          Owner and Operator
# 27             Terry M.                                   Treasurer
# 28            Cheryl E.                              Vice-President
# 29          Dr. Joan O.            President and Executive Director
# ...                 ...                                         ...
# 6415          Andrea H.                          Owner and designer
# 6416  Verified Reviewer                                         NaN
# 6417         Cameron M.                             Box Office Lead
# 6418  Verified Reviewer                                         NaN
# 6419  Verified Reviewer                                         NaN
# 6420  Verified Reviewer                                         NaN
# 6421             Roy K.                    UCCS Presents Box Office
# 6422           Grace A.                        Box Office Attendant
# 6423            Tiiu R.                                         NaN
# 6424           Luisa C.                                         NaN
# 6425            Cody A.                                         NaN
# 6426  Verified Reviewer                                         NaN
# 6427           Stacy C.                                         NaN
# 6428            Liam C.                          Part Time Employee
# 6429          Alicia W.                       Finance & HR Director
# 6430           Ramya A.                                         ISR
# 6431           Mindy F.               University Box Office Manager
# 6432        caroline s.                           Festival Director
# 6433            Rene B.                     Director of Development
# 6434        Nysselle C.                           Festival Producer
# 6435          Lauren W.         Director of Marketing & Development
# 6436          Samuel S.                          Executive Director
# 6437           LuAnn R.                    Patron Services Director
# 6438           Susan F.                           Business Director
# 6439          Monika L.                      Director of Operations
# 6440         Kristen H.             Customer Service Representative
# 6441            Lori R.                          Box Office Manager
# 6442          Donald D.  Director of Theater Operations/Programming
# 6443            Phil D.                         Corporate Recruiter
# 6444         Prajakt K.                          Content Evangelist
#
#                                 industry               usage paid_status  \
# 0                     Gambling & Casinos            2+ years          NO
# 1                                                        NaN          NO
# 2                 Religious Institutions  Less than 6 months          NO
# 3                                                        NaN          NO
# 4                                                        NaN          NO
# 5                                 Sports            2+ years          NO
# 6                                                   2+ years          NO
# 7                                                        NaN          NO
# 8                                                   2+ years          NO
# 9                                                   2+ years          NO
# 10                                                       NaN          NO
# 11                                                 1-2 years          NO
# 12                                                       NaN          NO
# 13                                                       NaN          NO
# 14                       Arts and Crafts  Less than 6 months          NO
# 15                                                       NaN          NO
# 16                                                       NaN          NO
# 17                         Entertainment            2+ years          NO
# 18    Non-Profit Organization Management            2+ years          NO
# 19                                        Less than 6 months          NO
# 20                                                       NaN          NO
# 21                                                       NaN          NO
# 22    Non-Profit Organization Management  Less than 6 months          NO
# 23                                                       NaN          NO
# 24                                                       NaN          NO
# 25                                                       NaN          NO
# 26                                                       NaN          NO
# 27                                                       NaN          NO
# 28                                        Less than 6 months          NO
# 29                                                       NaN          NO
# ...                                  ...                 ...         ...
# 6415                     Arts and Crafts         6-12 months         NGC
# 6416                                                                 NGC
# 6417                     Events Services         6-12 months         NGC
# 6418                 Writing and Editing                             NGC
# 6419                     Performing Arts                             NGC
# 6420                     Performing Arts                             NGC
# 6421                     Events Services  Less than 6 months         NGC
# 6422                     Events Services         6-12 months         NGC
# 6423                                                     NaN         NaN
# 6424                                                     NaN         NaN
# 6425                                                     NaN         NaN
# 6426                                                                 NGC
# 6427                                                     NaN         NaN
# 6428                       Entertainment  Less than 6 months         NGC
# 6429                       Entertainment         6-12 months          NO
# 6430                                      Less than 6 months         NGC
# 6431                    Higher Education            2+ years          VR
# 6432                                                2+ years          VR
# 6433            Motion Pictures and Film            2+ years          VR
# 6434                                                     NaN         NaN
# 6435                                                2+ years          VR
# 6436                       Entertainment         6-12 months          VR
# 6437                                             6-12 months          VR
# 6438                                                     NaN         NaN
# 6439            Motion Pictures and Film            2+ years         NGC
# 6440  Non-Profit Organization Management         6-12 months          NO
# 6441                                                     NaN         NaN
# 6442                                                     NaN         NaN
# 6443                                      Less than 6 months         NGC
# 6444                   Computer Software                 NaN          NO
#
#                source       date  total  ...  feature  support  value  \
# 0            Capterra 2019-02-20      5  ...      5.0      5.0    5.0
# 1            Capterra 2016-04-04      5  ...      5.0      5.0    5.0
# 2            Capterra 2016-10-13      5  ...      5.0      5.0    5.0
# 3            Capterra 2016-05-04      4  ...      5.0      5.0    5.0
# 4            Capterra 2016-04-22      5  ...      5.0      5.0    5.0
# 5            Capterra 2018-06-06      5  ...      5.0      5.0    5.0
# 6            Capterra 2017-12-05      5  ...      5.0      5.0    5.0
# 7            Capterra 2015-09-29      4  ...      5.0      4.0    5.0
# 8            Capterra 2018-06-07      5  ...      5.0      5.0    5.0
# 9            Capterra 2016-06-17      5  ...      5.0      5.0    4.0
# 10           Capterra 2015-06-24      5  ...      5.0      5.0    4.0
# 11           Capterra 2016-06-22      5  ...      5.0      5.0    5.0
# 12           Capterra 2016-02-10      4  ...      5.0      5.0    5.0
# 13           Capterra 2016-02-11      5  ...      5.0      5.0    5.0
# 14           Capterra 2016-11-14      5  ...      5.0      5.0    5.0
# 15           Capterra 2015-09-23      4  ...      5.0      5.0    5.0
# 16           Capterra 2015-03-19      4  ...      5.0      5.0    5.0
# 17           Capterra 2017-09-29      5  ...      5.0      5.0    5.0
# 18           Capterra 2016-06-13      5  ...      5.0      5.0    5.0
# 19           Capterra 2016-06-30      5  ...      4.0      5.0    5.0
# 20           Capterra 2015-03-22      5  ...      4.0      4.0    5.0
# 21           Capterra 2016-02-24      5  ...      4.0      5.0    5.0
# 22           Capterra 2016-07-29      5  ...      5.0      5.0    5.0
# 23           Capterra 2015-05-26      5  ...      5.0      5.0    5.0
# 24           Capterra 2016-06-02      4  ...      5.0      5.0    5.0
# 25           Capterra 2015-10-27      5  ...      5.0      5.0    5.0
# 26           Capterra 2016-05-02      5  ...      5.0      5.0    5.0
# 27           Capterra 2016-05-19      5  ...      5.0      5.0    5.0
# 28           Capterra 2018-04-05      5  ...      5.0      5.0    5.0
# 29           Capterra 2016-04-27      5  ...      5.0      5.0    5.0
# ...               ...        ...    ...  ...      ...      ...    ...
# 6415         Capterra 2018-11-27      5  ...      5.0      5.0    4.0
# 6416              NaN 2018-01-09      5  ...      5.0      3.0    NaN
# 6417         Capterra 2019-04-11      3  ...      4.0      3.0    NaN
# 6418              NaN 2019-05-31      5  ...      4.0      NaN    NaN
# 6419              NaN 2017-10-04      4  ...      4.0      5.0    4.0
# 6420              NaN 2018-02-01      3  ...      4.0      2.0    4.0
# 6421         Capterra 2019-04-11      3  ...      4.0      4.0    4.0
# 6422         Capterra 2019-05-17      4  ...      4.0      3.0    3.0
# 6423         Capterra 2017-04-12      4  ...      4.0      4.0    NaN
# 6424  Software Advice 2015-03-04      4  ...      4.0      4.5    NaN
# 6425         Capterra 2017-02-01      5  ...      5.0      4.0    NaN
# 6426              NaN 2017-10-17      5  ...      4.0      5.0    5.0
# 6427         Capterra 2016-11-21      5  ...      5.0      5.0    NaN
# 6428         Capterra 2018-09-08      5  ...      5.0      NaN    NaN
# 6429         Capterra 2018-04-24      5  ...      5.0      5.0    5.0
# 6430  Software Advice 2017-12-04      4  ...      5.0      4.0    4.0
# 6431         Capterra 2018-04-11      4  ...      4.0      5.0    5.0
# 6432         Capterra 2018-04-11      4  ...      4.0      5.0    5.0
# 6433         Capterra 2018-04-10      4  ...      4.0      5.0    4.0
# 6434         Capterra 2016-05-16      4  ...      NaN      5.0    NaN
# 6435         Capterra 2018-04-10      5  ...      5.0      5.0    NaN
# 6436         Capterra 2018-04-11      5  ...      4.0      5.0    4.0
# 6437         Capterra 2018-04-12      5  ...      5.0      4.0    5.0
# 6438         Capterra 2016-05-16      5  ...      NaN      5.0    NaN
# 6439         Capterra 2019-01-04      3  ...      4.0      5.0    3.0
# 6440         Capterra 2019-07-06      5  ...      5.0      5.0    5.0
# 6441         Capterra 2016-05-20      5  ...      NaN      5.0    NaN
# 6442         Capterra 2016-05-16      5  ...      NaN      5.0    NaN
# 6443  Software Advice 2018-10-24      4  ...      5.0      5.0    4.0
# 6444           GetApp 2018-08-10      5  ...      NaN      NaN    NaN
#
#       recommend                                           comments  \
# 0          10.0                                                NaN
# 1          10.0  After much research into the various vendors f...
# 2          10.0                                                NaN
# 3          10.0  I have worked with these people and this syste...
# 4          10.0  PROS-\n\n-24/7 support and customer service\n\...
# 5           9.0                                                NaN
# 6           9.0                                                NaN
# 7           9.0  Pros: The system is mostly user friendly on th...
# 8           9.0                                                NaN
# 9           9.0                                                NaN
# 10          9.0  We used to spend countless hours chasing ticke...
# 11         10.0                                                NaN
# 12         10.0  The software itself is not something easy to l...
# 13         10.0  Greatly appreciate the wonderful customer serv...
# 14         10.0                                                NaN
# 15         10.0  System administration is easy\n\nUser interfac...
# 16         10.0  Although there are a lot of components to sett...
# 17         10.0                                                NaN
# 18         10.0                                                NaN
# 19         10.0                                                NaN
# 20         10.0  Overall Tix.com has done a great job for my co...
# 21         10.0  We chose to partner with tix.com two years ago...
# 22         10.0  Very happy with Tix. Our account manager, Stev...
# 23         10.0  The only complaint I have had is from my custo...
# 24         10.0  My husband and I have been producing an event ...
# 25         10.0  Once you gain familiarity with the software, i...
# 26         10.0  Tix has been a great addition to my business. ...
# 27         10.0  We are a small community theater group and we ...
# 28         10.0                                                NaN
# 29         10.0  This is our second year using Tix.com for onli...
# ...         ...                                                ...
# 6415        9.0  Shop around. There has to be a more efficient ...
# 6416        NaN  Shop around. There has to be a more efficient ...
# 6417        4.0  Shop around. There has to be a more efficient ...
# 6418        7.0  Shop around. There has to be a more efficient ...
# 6419        8.0  Shop around. There has to be a more efficient ...
# 6420        7.0  Shop around. There has to be a more efficient ...
# 6421        6.0  Shop around. There has to be a more efficient ...
# 6422        5.0  Shop around. There has to be a more efficient ...
# 6423        NaN  I didn't work with this software for that long...
# 6424        9.0  I didn't work with this software for that long...
# 6425        NaN  Tessitura is the biggest and worst CRM you can...
# 6426        8.0  Tessitura is the biggest and worst CRM you can...
# 6427        NaN  I worked for a nonprofit and this was a great ...
# 6428        8.0  I worked for a nonprofit and this was a great ...
# 6429       10.0                                                NaN
# 6430        8.0                                                NaN
# 6431       10.0                                                NaN
# 6432        9.0                                                NaN
# 6433        9.0                                                NaN
# 6434        NaN  The pros - much more user friendly than other ...
# 6435        NaN  The pros - much more user friendly than other ...
# 6436        9.0  The pros - much more user friendly than other ...
# 6437       10.0  The pros - much more user friendly than other ...
# 6438        NaN  We've been using Agile for many years and have...
# 6439        6.0  We've been using Agile for many years and have...
# 6440       10.0  We've been using Agile for many years and have...
# 6441        NaN  The software, on the whole, is user-friendly a...
# 6442        NaN  Switching over to Agile was one of the best de...
# 6443        8.0  Switching over to Agile was one of the best de...
# 6444        NaN  Switching over to Agile was one of the best de...
#
#                                                    pros  \
# 0     Customer service is the BEST! No words can des...
# 1                                                   NaN
# 2     Patron experience is excellent. Help library i...
# 3                                                   NaN
# 4                                                   NaN
# 5     It is a simple program to use. Easy Setup even...
# 6     Online seat selection ordering is very efficie...
# 7                                                   NaN
# 8     Customizable for our events and being able to ...
# 9     Ease of ticket sales. Nice reports to confirm ...
# 10                                                  NaN
# 11      Everything all in one place and easy to access.
# 12                                                  NaN
# 13                                                  NaN
# 14                    Easy to use...easy to understand.
# 15                                                  NaN
# 16                                                  NaN
# 17    The software is straight forward in it's set u...
# 18    Extremely easy to use. We do a lot of the same...
# 19    Cost, ability to customize seating arrangement...
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28    Easy to use, navigate, personalize and access....
# 29                                                  NaN
# ...                                                 ...
# 6415  I recently started using tessitura and I like ...
# 6416  There are so many functions to learn about thi...
# 6417  Tessitura has a lot of good ticketing features...
# 6418  For donor organization, easy and effective wit...
# 6419  Tessitura allows you to input and seat based o...
# 6420  Ease of use in the ticketing function. One is ...
# 6421  It is an effective organizational and ticketin...
# 6422  Tessitura is organized and can handle the comp...
# 6423  Tessitura is organized and can handle the comp...
# 6424  Ability to incorporate both development and bo...
# 6425  Ability to incorporate both development and bo...
# 6426  It is SO big. The number of features is really...
# 6427  It is SO big. The number of features is really...
# 6428  Tessitura is a fantastic software that helps m...
# 6429  We had a very long list of specific criteria w...
# 6430  Responding to Change Perhaps the biggest advan...
# 6431  Agile Ticketing Solutions is an in depth and a...
# 6432  Agile is flexible and user friendly and allows...
# 6433  The API communication between Agile and DPO sa...
# 6434  The API communication between Agile and DPO sa...
# 6435  Aside from extremely helpful staff and support...
# 6436  The Agile system has been extremely reliable, ...
# 6437  I like that there are regular updates and new ...
# 6438  I like that there are regular updates and new ...
# 6439  It has great customer service - always ready t...
# 6440  It is easy to use and perfectly functional for...
# 6441  It is easy to use and perfectly functional for...
# 6442  It is easy to use and perfectly functional for...
# 6443  - Bottomless set of features, bells and whistl...
# 6444  - Bottomless set of features, bells and whistl...
#
#                                                    cons  \
# 0     Not many people know about Tix. If more people...
# 1                                                   NaN
# 2     Sometimes the reports do not output to excel c...
# 3                                                   NaN
# 4                                                   NaN
# 5     Lack of social media connection. Lack of infor...
# 6     Customer data maintenance is a bit lean, sorti...
# 7                                                   NaN
# 8     Would like more ticket printer choices. Would ...
# 9     Since I only use the program once every 6 mont...
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                      None, honestly.
# 15                                                  NaN
# 16                                                  NaN
# 17    Our company is in North Carolina and Tix.com i...
# 18    Nothing. We haven't had any complaints at all....
# 19    Our only issue was checking in our guests at t...
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28    There's very little negative I can say about T...
# 29                                                  NaN
# ...                                                 ...
# 6415  Only con I have is for the saving button, it s...
# 6416  It is a bit complicated and you do need a spec...
# 6417  This software is really difficult to learn and...
# 6418  Ugh, ok, repeat entries were the scourge of my...
# 6419  Tessitura is a large and complicated software....
# 6420  Does not have the full capacity of moves manag...
# 6421  Many of its options are counter-intuitive, and...
# 6422  It is very archaic-looking, confusing, and har...
# 6423  It is very archaic-looking, confusing, and har...
# 6424  Difficult to access 24/7; limited abilities; n...
# 6425  Difficult to access 24/7; limited abilities; n...
# 6426  Unfortunately, the sheer number of functions c...
# 6427  Unfortunately, the sheer number of functions c...
# 6428  Because the work I do on Tessitura is relative...
# 6429  This is a big platform that can do so many thi...
# 6430  Lack of Understanding Flexibility Can Lead to ...
# 6431  Reporting: There are several options to choose...
# 6432  I have had an overall positive experience with...
# 6433  Too many reports and none of them do exactly w...
# 6434  Too many reports and none of them do exactly w...
# 6435  Sometimes programs that can do so much can see...
# 6436  Inventory Management could be stronger, but th...
# 6437  The software is great but there is sometimes t...
# 6438  The software is great but there is sometimes t...
# 6439  the interface is very outdated and some featur...
# 6440  They will have minor things I do not like, but...
# 6441  They will have minor things I do not like, but...
# 6442  They will have minor things I do not like, but...
# 6443  - Not overtly intuitive so it takes some time ...
# 6444  - Not overtly intuitive so it takes some time ...
#
#                                                 overall  \
# 0     I had no background on ticketing systems, Tix ...
# 1                                                   NaN
# 2     We wanted an easy-to-use system where patrons ...
# 3                                                   NaN
# 4                                                   NaN
# 5                                  Selling tickets 24-7
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9     Thanks to Steve for helping me navigate the pr...
# 10                                                  NaN
# 11    Interface is easy to use, customer service is ...
# 12                                                  NaN
# 13                                                  NaN
# 14    We at the Miami Childrens Theater were looking...
# 15                                                  NaN
# 16                                                  NaN
# 17    Simplicity of use, affordable price and consis...
# 18    We are a community theater that puts on 3 or s...
# 19    This is the first time I have used a program l...
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 6415  Overall I like the program. It has everything ...
# 6416  Overall I like the program. It has everything ...
# 6417  Overall I have not been happy with Tessitura. ...
# 6418  Every arts organization uses Tessitura for a r...
# 6419  Every arts organization uses Tessitura for a r...
# 6420  Every arts organization uses Tessitura for a r...
# 6421  I had trouble learning how to use and be effec...
# 6422  I had trouble learning how to use and be effec...
# 6423  I had trouble learning how to use and be effec...
# 6424  I had trouble learning how to use and be effec...
# 6425  I had trouble learning how to use and be effec...
# 6426  I had trouble learning how to use and be effec...
# 6427  I had trouble learning how to use and be effec...
# 6428  I had trouble learning how to use and be effec...
# 6429  We were able to improve the patron experience ...
# 6430  We were able to improve the patron experience ...
# 6431               Please refer to the section on Pros.
# 6432                           so far I am very pleased
# 6433  Having a hosted system that is constantly evol...
# 6434  Having a hosted system that is constantly evol...
# 6435  Having a hosted system that is constantly evol...
# 6436  A far more advanced total ticketing and member...
# 6437  A far more advanced total ticketing and member...
# 6438  A far more advanced total ticketing and member...
# 6439  Agile has served us well for several years, bu...
# 6440                                       So positive!
# 6441                                       So positive!
# 6442                                       So positive!
# 6443                                       So positive!
# 6444                                       So positive!
#
#                         recommendations to other buyers  employees
# 0                                                   NaN  1001-5000
# 1                                                   NaN
# 2                                                   NaN     51-200
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN      11-50
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14    Really like the support staff . I am not the m...      11-50
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN     51-200
# 18                                                  NaN       1-10
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN       1-10
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...        ...
# 6415                                                NaN
# 6416                                                NaN
# 6417                                                NaN     51-200
# 6418                                                NaN
# 6419                                                NaN     51-200
# 6420                                                NaN     51-200
# 6421                                                NaN      11-50
# 6422                                                NaN     51-200
# 6423                                                NaN
# 6424  Unique to the arts industry, some excellent sp...
# 6425  Unique to the arts industry, some excellent sp...
# 6426  Unique to the arts industry, some excellent sp...
# 6427  Unique to the arts industry, some excellent sp...
# 6428  Unique to the arts industry, some excellent sp...    201-500
# 6429                                                NaN     51-200
# 6430                                                NaN
# 6431                                                NaN    201-500
# 6432                                                NaN
# 6433                                                NaN      11-50
# 6434                                                NaN
# 6435                                                NaN
# 6436                                                NaN      11-50
# 6437                                                NaN
# 6438                                                NaN
# 6439                                                NaN       1-10
# 6440                                                NaN     51-200
# 6441                                                NaN
# 6442                                                NaN
# 6443                                                NaN
# 6444                                                NaN     51-200
#
# [6445 rows x 21 columns]

# %%
df.shape
# Out:
# (6445, 21)

# %%
df.groupby('company').describe()
# Out:
#                               total                                            \
#                               count      mean       std  min   25%  50%   75%
# company
# accelevents                    78.0  4.820513  0.418519  3.0  5.00  5.0  5.00
# accesso_showare                44.0  4.659091  0.525763  3.0  4.00  5.0  5.00
# agile ticketing                16.0  4.500000  0.632456  3.0  4.00  5.0  5.00
# arts people                    16.0  4.750000  0.577350  3.0  5.00  5.0  5.00
# attendstar                     62.0  4.661290  0.599003  3.0  4.00  5.0  5.00
# audienceview                    6.0  4.166667  0.752773  3.0  4.00  4.0  4.75
# backstage                      11.0  5.000000  0.000000  5.0  5.00  5.0  5.00
# betterez                       14.0  4.714286  0.468807  4.0  4.25  5.0  5.00
# big tickets                    20.0  4.900000  0.307794  4.0  5.00  5.0  5.00
# bookitbee                       8.0  4.875000  0.353553  4.0  5.00  5.0  5.00
# bookwhen                       87.0  4.816092  0.389655  4.0  5.00  5.0  5.00
# brown paper tickets            13.0  4.461538  0.660225  3.0  4.00  5.0  5.00
# brushfire                      80.0  4.662500  0.635326  2.0  4.00  5.0  5.00
# coconut tickets                 6.0  4.666667  0.516398  4.0  4.25  5.0  5.00
# elevent                         5.0  4.800000  0.447214  4.0  5.00  5.0  5.00
# etix                            7.0  2.000000  1.732051  1.0  1.00  1.0  2.50
# evenium net                    28.0  4.464286  0.637248  3.0  4.00  5.0  5.00
# event_essentials               64.0  4.953125  0.213042  4.0  5.00  5.0  5.00
# eventbank                      43.0  4.697674  0.464701  4.0  4.00  5.0  5.00
# eventbrite                   1902.0  4.582019  0.652235  1.0  4.00  5.0  5.00
# eventgrid by doubledutch        7.0  4.571429  0.534522  4.0  4.00  5.0  5.00
# eventix                       777.0  4.619048  0.524205  3.0  4.00  5.0  5.00
# eventsframe                    38.0  4.657895  0.534047  3.0  4.00  5.0  5.00
# explara ticketing software     17.0  4.764706  0.437237  4.0  5.00  5.0  5.00
# facebook ticketing system       7.0  3.714286  1.603567  1.0  3.00  4.0  5.00
# freshtix                       15.0  4.933333  0.258199  4.0  5.00  5.0  5.00
# gatemaster                      7.0  4.142857  1.463850  1.0  4.00  5.0  5.00
# gesture                        76.0  4.605263  0.674862  1.0  4.00  5.0  5.00
# giveffect                      33.0  4.636364  0.548759  3.0  4.00  5.0  5.00
# givesmart                      76.0  4.605263  0.674862  1.0  4.00  5.0  5.00
# ...                             ...       ...       ...  ...   ...  ...   ...
# simpletix                      54.0  4.685185  0.722263  2.0  5.00  5.0  5.00
# sparxo                         67.0  4.671642  0.682865  1.0  4.50  5.0  5.00
# spektrix                       10.0  5.000000  0.000000  5.0  5.00  5.0  5.00
# spingo                          5.0  3.600000  1.516575  2.0  2.00  4.0  5.00
# sro4                           11.0  3.909091  1.513575  1.0  4.00  4.0  5.00
# syam software                  15.0  4.200000  1.082326  1.0  4.00  4.0  5.00
# tessitura software             24.0  4.208333  0.883627  2.0  4.00  4.0  5.00
# theatre manager                15.0  4.066667  0.703732  3.0  4.00  4.0  4.50
# thundertix                    168.0  4.702381  0.584834  1.0  4.00  5.0  5.00
# tick-it!                       19.0  4.684211  0.477567  4.0  4.00  5.0  5.00
# ticket_tailor                 181.0  4.911602  0.284660  4.0  5.00  5.0  5.00
# ticketbud                      23.0  4.695652  0.558796  3.0  4.50  5.0  5.00
# ticketfly                      18.0  4.333333  1.283378  1.0  4.00  5.0  5.00
# ticketinghub                   24.0  4.958333  0.204124  4.0  5.00  5.0  5.00
# ticketleap                     10.0  4.800000  0.421637  4.0  5.00  5.0  5.00
# ticketmanager                  22.0  4.363636  0.657952  3.0  4.00  4.0  5.00
# ticketpeak                     30.0  4.566667  0.504007  4.0  4.00  5.0  5.00
# ticketsage custom solutions     6.0  4.166667  0.408248  4.0  4.00  4.0  4.00
# ticketsetup                    11.0  5.000000  0.000000  5.0  5.00  5.0  5.00
# ticketsource                  308.0  4.740260  0.533017  1.0  5.00  5.0  5.00
# tix                           138.0  4.833333  0.411217  3.0  5.00  5.0  5.00
# townscript                     52.0  4.807692  0.444507  3.0  5.00  5.0  5.00
# universe                       33.0  4.424242  0.902438  1.0  4.00  5.0  5.00
# vbo_tickets                    76.0  4.763158  0.458066  3.0  5.00  5.0  5.00
# vendini                        65.0  4.584615  0.726557  1.0  4.00  5.0  5.00
# via                             8.0  3.625000  1.767767  1.0  2.50  4.5  5.00
# weemss                         50.0  4.680000  0.652781  2.0  5.00  5.0  5.00
# wintix / webtix                19.0  4.684211  0.477567  4.0  4.00  5.0  5.00
# yapsody                        12.0  4.750000  0.452267  4.0  4.75  5.0  5.00
# zaui software                  28.0  4.428571  0.741798  2.0  4.00  5.0  5.00
#
#                                     ease            ... value      recommend  \
#                              max   count      mean  ...   75%  max     count
# company                                             ...
# accelevents                  5.0    78.0  4.782051  ...   5.0  5.0      78.0
# accesso_showare              5.0    44.0  4.568182  ...   5.0  5.0      44.0
# agile ticketing              5.0    15.0  3.933333  ...   5.0  5.0      10.0
# arts people                  5.0    16.0  4.875000  ...   5.0  5.0       6.0
# attendstar                   5.0    62.0  4.741935  ...   5.0  5.0      62.0
# audienceview                 5.0     6.0  4.333333  ...   2.0  2.0       1.0
# backstage                    5.0    11.0  5.000000  ...   5.0  5.0      11.0
# betterez                     5.0    14.0  4.785714  ...   5.0  5.0      13.0
# big tickets                  5.0    20.0  4.700000  ...   5.0  5.0      15.0
# bookitbee                    5.0     8.0  5.000000  ...   5.0  5.0       1.0
# bookwhen                     5.0    87.0  4.678161  ...   5.0  5.0      87.0
# brown paper tickets          5.0    13.0  4.230769  ...   5.0  5.0       8.0
# brushfire                    5.0    80.0  4.425000  ...   5.0  5.0      80.0
# coconut tickets              5.0     6.0  4.500000  ...   5.0  5.0       6.0
# elevent                      5.0     5.0  4.600000  ...   5.0  5.0       4.0
# etix                         5.0     7.0  2.285714  ...   4.0  4.0       2.0
# evenium net                  5.0    28.0  4.142857  ...   5.0  5.0      18.0
# event_essentials             5.0    64.0  4.953125  ...   5.0  5.0      64.0
# eventbank                    5.0    43.0  4.651163  ...   5.0  5.0      43.0
# eventbrite                   5.0  1902.0  4.599895  ...   5.0  5.0    1902.0
# eventgrid by doubledutch     5.0     7.0  4.857143  ...   5.0  5.0       5.0
# eventix                      5.0   777.0  4.716860  ...   5.0  5.0     777.0
# eventsframe                  5.0    38.0  4.763158  ...   5.0  5.0      38.0
# explara ticketing software   5.0    17.0  4.705882  ...   5.0  5.0      15.0
# facebook ticketing system    5.0     7.0  4.142857  ...   5.0  5.0       5.0
# freshtix                     5.0    15.0  4.800000  ...   5.0  5.0      11.0
# gatemaster                   5.0     7.0  4.142857  ...   5.0  5.0       6.0
# gesture                      5.0    76.0  4.460526  ...   5.0  5.0      76.0
# giveffect                    5.0    33.0  4.606061  ...   5.0  5.0      33.0
# givesmart                    5.0    76.0  4.460526  ...   5.0  5.0      76.0
# ...                          ...     ...       ...  ...   ...  ...       ...
# simpletix                    5.0    54.0  4.370370  ...   5.0  5.0      54.0
# sparxo                       5.0    67.0  4.522388  ...   5.0  5.0      67.0
# spektrix                     5.0    10.0  4.500000  ...   5.0  5.0       7.0
# spingo                       5.0     5.0  3.400000  ...   5.0  5.0       3.0
# sro4                         5.0    11.0  3.818182  ...   NaN  NaN       0.0
# syam software                5.0    15.0  3.866667  ...   5.0  5.0      14.0
# tessitura software           5.0    24.0  3.125000  ...   4.5  5.0      20.0
# theatre manager              5.0    15.0  3.733333  ...   5.0  5.0      10.0
# thundertix                   5.0   168.0  4.577381  ...   5.0  5.0     168.0
# tick-it!                     5.0    19.0  4.789474  ...   5.0  5.0       9.0
# ticket_tailor                5.0   181.0  4.872928  ...   5.0  5.0     181.0
# ticketbud                    5.0    23.0  4.521739  ...   5.0  5.0       8.0
# ticketfly                    5.0    18.0  4.277778  ...   5.0  5.0       9.0
# ticketinghub                 5.0    24.0  4.833333  ...   5.0  5.0      16.0
# ticketleap                   5.0     9.0  4.666667  ...   5.0  5.0       5.0
# ticketmanager                5.0    22.0  3.954545  ...   5.0  5.0      14.0
# ticketpeak                   5.0    30.0  4.433333  ...   5.0  5.0      14.0
# ticketsage custom solutions  5.0     6.0  4.500000  ...   NaN  NaN       0.0
# ticketsetup                  5.0    11.0  5.000000  ...   5.0  5.0      11.0
# ticketsource                 5.0   308.0  4.597403  ...   5.0  5.0     308.0
# tix                          5.0   138.0  4.702899  ...   5.0  5.0     138.0
# townscript                   5.0    52.0  4.730769  ...   5.0  5.0      52.0
# universe                     5.0    33.0  4.424242  ...   4.0  5.0      33.0
# vbo_tickets                  5.0    76.0  4.197368  ...   5.0  5.0      76.0
# vendini                      5.0    65.0  4.661538  ...   5.0  5.0      65.0
# via                          5.0     8.0  4.000000  ...   5.0  5.0       3.0
# weemss                       5.0    50.0  4.600000  ...   5.0  5.0      50.0
# wintix / webtix              5.0    19.0  4.526316  ...   5.0  5.0       2.0
# yapsody                      5.0    12.0  4.750000  ...   5.0  5.0       8.0
# zaui software                5.0    28.0  4.250000  ...   5.0  5.0      24.0
#
#                                                                             \
#                                   mean       std   min    25%   50%    75%
# company
# accelevents                   9.641026  0.720288   6.0   9.25  10.0  10.00
# accesso_showare               8.659091  0.963115   7.0   8.00   8.0  10.00
# agile ticketing               8.900000  1.286684   6.0   8.25   9.0  10.00
# arts people                  10.000000  0.000000  10.0  10.00  10.0  10.00
# attendstar                    9.032258  1.436842   5.0   8.25  10.0  10.00
# audienceview                  5.000000       NaN   5.0   5.00   5.0   5.00
# backstage                    10.000000  0.000000  10.0  10.00  10.0  10.00
# betterez                      9.307692  0.854850   8.0   9.00  10.0  10.00
# big tickets                   9.933333  0.258199   9.0  10.00  10.0  10.00
# bookitbee                    10.000000       NaN  10.0  10.00  10.0  10.00
# bookwhen                      9.666667  1.063853   5.0  10.00  10.0  10.00
# brown paper tickets           8.500000  1.511858   6.0   7.75   8.5  10.00
# brushfire                     9.187500  1.341582   3.0   9.00  10.0  10.00
# coconut tickets               9.500000  0.836660   8.0   9.25  10.0  10.00
# elevent                       9.750000  0.500000   9.0   9.75  10.0  10.00
# etix                          9.000000  1.414214   8.0   8.50   9.0   9.50
# evenium net                   8.722222  1.526455   5.0   8.25   9.0  10.00
# event_essentials              9.687500  0.663684   8.0  10.00  10.0  10.00
# eventbank                     9.348837  0.841872   8.0   9.00  10.0  10.00
# eventbrite                    8.786015  1.433041   1.0   8.00   9.0  10.00
# eventgrid by doubledutch      8.600000  2.190890   5.0   8.00  10.0  10.00
# eventix                       8.619048  1.303859   2.0   8.00   9.0  10.00
# eventsframe                   9.105263  1.247473   5.0   9.00  10.0  10.00
# explara ticketing software    9.333333  0.723747   8.0   9.00   9.0  10.00
# facebook ticketing system     7.800000  3.271085   2.0   9.00   9.0   9.00
# freshtix                      9.909091  0.301511   9.0  10.00  10.0  10.00
# gatemaster                    9.333333  1.211060   7.0   9.25  10.0  10.00
# gesture                       8.855263  1.323671   4.0   8.00   9.0  10.00
# giveffect                     8.848485  1.752163   3.0   8.00  10.0  10.00
# givesmart                     8.855263  1.323671   4.0   8.00   9.0  10.00
# ...                                ...       ...   ...    ...   ...    ...
# simpletix                     9.518519  1.745514   1.0  10.00  10.0  10.00
# sparxo                        9.149254  1.520105   3.0   9.00  10.0  10.00
# spektrix                      9.714286  0.755929   8.0  10.00  10.0  10.00
# spingo                        9.666667  0.577350   9.0   9.50  10.0  10.00
# sro4                               NaN       NaN   NaN    NaN   NaN    NaN
# syam software                 8.714286  2.431479   1.0   8.25  10.0  10.00
# tessitura software            7.300000  1.750188   4.0   6.00   8.0   8.25
# theatre manager               8.400000  1.712698   5.0   7.25   8.5  10.00
# thundertix                    9.470238  1.066224   4.0   9.00  10.0  10.00
# tick-it!                      9.555556  1.013794   7.0  10.00  10.0  10.00
# ticket_tailor                 9.624309  0.634442   7.0   9.00  10.0  10.00
# ticketbud                     9.625000  0.744024   8.0   9.75  10.0  10.00
# ticketfly                     8.333333  1.732051   5.0   7.00   9.0  10.00
# ticketinghub                  9.750000  0.774597   7.0  10.00  10.0  10.00
# ticketleap                    9.000000  1.414214   7.0   8.00  10.0  10.00
# ticketmanager                 8.642857  1.277446   7.0   7.25   9.0  10.00
# ticketpeak                    9.285714  1.069045   7.0   8.25  10.0  10.00
# ticketsage custom solutions        NaN       NaN   NaN    NaN   NaN    NaN
# ticketsetup                   9.636364  0.924416   7.0  10.00  10.0  10.00
# ticketsource                  9.944805  0.411803   6.0  10.00  10.0  10.00
# tix                           9.753623  0.509925   8.0  10.00  10.0  10.00
# townscript                    9.250000  1.234710   5.0   9.00  10.0  10.00
# universe                      9.121212  0.484612   8.0   9.00   9.0   9.00
# vbo_tickets                   9.236842  1.056641   5.0   9.00  10.0  10.00
# vendini                       8.584615  2.142518   3.0   7.00  10.0  10.00
# via                           8.666667  1.527525   7.0   8.00   9.0   9.50
# weemss                        9.300000  0.974156   6.0   9.00  10.0  10.00
# wintix / webtix               6.500000  4.949747   3.0   4.75   6.5   8.25
# yapsody                       9.000000  1.195229   7.0   8.00   9.5  10.00
# zaui software                 8.750000  1.452135   5.0   8.00   9.0  10.00
#
#
#                               max
# company
# accelevents                  10.0
# accesso_showare              10.0
# agile ticketing              10.0
# arts people                  10.0
# attendstar                   10.0
# audienceview                  5.0
# backstage                    10.0
# betterez                     10.0
# big tickets                  10.0
# bookitbee                    10.0
# bookwhen                     10.0
# brown paper tickets          10.0
# brushfire                    10.0
# coconut tickets              10.0
# elevent                      10.0
# etix                         10.0
# evenium net                  10.0
# event_essentials             10.0
# eventbank                    10.0
# eventbrite                   10.0
# eventgrid by doubledutch     10.0
# eventix                      10.0
# eventsframe                  10.0
# explara ticketing software   10.0
# facebook ticketing system    10.0
# freshtix                     10.0
# gatemaster                   10.0
# gesture                      10.0
# giveffect                    10.0
# givesmart                    10.0
# ...                           ...
# simpletix                    10.0
# sparxo                       10.0
# spektrix                     10.0
# spingo                       10.0
# sro4                          NaN
# syam software                10.0
# tessitura software           10.0
# theatre manager              10.0
# thundertix                   10.0
# tick-it!                     10.0
# ticket_tailor                10.0
# ticketbud                    10.0
# ticketfly                    10.0
# ticketinghub                 10.0
# ticketleap                   10.0
# ticketmanager                10.0
# ticketpeak                   10.0
# ticketsage custom solutions   NaN
# ticketsetup                  10.0
# ticketsource                 10.0
# tix                          10.0
# townscript                   10.0
# universe                     10.0
# vbo_tickets                  10.0
# vendini                      10.0
# via                          10.0
# weemss                       10.0
# wintix / webtix              10.0
# yapsody                      10.0
# zaui software                10.0
#
# [87 rows x 48 columns]

# %%
df['source'].value_counts()
# Out:
# Capterra           5644
# Software Advice     650
# GetApp               87
# Name: source, dtype: int64

# %%
# tipsGrid = sns.FacetGrid(tips, row='sex', col='smoker', hue='time', palette="Set2")
# tipsGrid.map(sns.regplot,'total_bill','tip')
# tipsGrid.add_legend()
